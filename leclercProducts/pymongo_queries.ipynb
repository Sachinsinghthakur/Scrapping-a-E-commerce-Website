# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pymongo
conn=pymongo.MongoClient("mongodb+srv://SachinSinghThakur:SachinSinghThakur@leclercproducts.rfngv3b.mongodb.net/?retryWrites=true&w=majority")

# %%
db=conn["SachinThakur"]

# %%
db.collection_names()

# %% [markdown]
# <h2>How many products did you scrape

# %%
total_documents=0
for collection in db.collection_names():
    total_documents+=db[collection].count()
print(total_documents)
# Out:
# 57703

# %% [markdown]
# <h2>how many products have discount on them

# %%
total_documents=0
for collection in db.collection_names():
    total_documents+=db[collection].find({"$expr":{"$ne":["$sale_price", "$original_price"]}}).count()
print(total_documents)
# Out:
# 12521

# %% [markdown]
# <h2>how many unique brands in the collection</h2><br>
# for single collection <br>
# <h4>len(db["vetement homme"].distinct("brand"))

# %%
temp_set=set()
for collection in db.collection_names():
    for i in db[collection].distinct("brand"):
        temp_set.add(i)
len(temp_set)
# Out:
# 872

# %% [markdown]
# <h2>what is the count of distinct product_url based on category vetement-homme

# %%
len(db["vetement homme"].distinct("product_page_url"))
# Out:
# 278

# %% [markdown]
# <h2>how many products have sale_price greater than 300

# %%
query_pipeline_2=[   {
                       "$match":{
                          "sale_price": {
                                  "$gt": 300
                                       }
                                   }
                    },
                    {
                        "$count":"total"
                    }
                   ]

# %%
total_documents=0
for collection in db.collection_names():
    for output in db[collection].aggregate(query_pipeline_2):
        output=dict(output)
        total_documents+=output["total"]
    
print(total_documents)
# Out:
# 57668

# %% [markdown]
# <h2> how many products have sale_price greater than original_price

# %%
total_documents=0
for collection in db.collection_names():
    total_documents+=db[collection].find({"$expr":{"$gt":["$sale_price", "$original_price"]}}).count()
print(total_documents)
# Out:
# 0

# %% [markdown]
# <h2> How many products have 50% discount?

# %%
total_documents=0
for collection in db.collection_names():
    total_documents+=db[collection].find({"$expr":{"$eq":["$sale_price",{"$multiply": ["$original_price",0.5]}]}}).count()
print(total_documents)
# Out:
# 31

# %% [markdown]
# <h2> how many products have discount % greater than 30%

# %%
total_documents=0
for collection in db.collection_names():
    total_documents+=db[collection].find({"$expr":{"$lt":["$sale_price",{"$multiply": ["$original_price",0.7]}]}}).count()
print(total_documents)
# Out:
# 1305

# %% [markdown]
# <h2> how many products have ean in them

# %%
total_documents=0
for collection in db.collection_names():
    total_documents+=db[collection].find({"ean": {"$exists":True }}).count()
print(total_documents)
# Out:
# 57703

# %% [markdown]
# <h2>what is the count of products in each brand

# %%
query_pipeline_1 = [{"$group": {
                                "_id":"$brand",
                                "number_of_products":{ "$count":{} }
                                    }
                                }]

# %%
for collection in db.collection_names():
    for brand in db[collection].aggregate(query_pipeline_1):
        print(brand)
# Out:
# {'_id': 'Jumpking Trampolines', 'number_of_products': 7}
# {'_id': 'Fast-Jump', 'number_of_products': 5}
# {'_id': 'Jump4Fun', 'number_of_products': 78}
# {'_id': 'Play4Fun', 'number_of_products': 10}
# {'_id': 'Hudora', 'number_of_products': 4}
# {'_id': 'beneffito', 'number_of_products': 2}
# {'_id': 'Moose Toys', 'number_of_products': 5}
# {'_id': 'Tectake', 'number_of_products': 1}
# {'_id': 'Kangui', 'number_of_products': 134}
# {'_id': 'JT2D', 'number_of_products': 4}
# {'_id': 'Habitat et Jardin', 'number_of_products': 18}
# {'_id': 'Devessport', 'number_of_products': 5}
# {'_id': 'jardideco', 'number_of_products': 36}
# {'_id': 'Homcom', 'number_of_products': 13}
# {'_id': 'Kaia Sports', 'number_of_products': 3}
# {'_id': 'HyperMotion', 'number_of_products': 2}
# {'_id': 'Berg Toys', 'number_of_products': 217}
# {'_id': 'Trigano', 'number_of_products': 2}
# {'_id': 'Smart Trike', 'number_of_products': 2}
# {'_id': 'Sans marque', 'number_of_products': 34}
# ...
